# %% [markdown]
# ## Work
# 1. 請自行定義一個 loss function, 為 0.3 * focal loss + 0.7 cross-entropy，訓練並比較結果

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
import tensorflow as tf
import keras.backend as K

"""Code Here
撰寫一個 loss function, 使其可以結合 focal loss 與 crossentropy loss
"""
def combined_loss(ce_weight, gamma=2., alpha=4.):
    """Define the customized loss."""
    gamma = float(gamma)
    alpha = float(alpha)
    def combined_loss_fixed(y_true, y_pred):
        epsilon = 1e-8
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)

        model_out = tf.add(y_pred, epsilon)
        ce = tf.multiply(y_true, -tf.math.log(model_out))
        weight = tf.multiply(y_true, tf.pow(tf.subtract(1., model_out), gamma))
        fl = tf.multiply(alpha, tf.multiply(weight, ce))
        reduced_fl = tf.reduce_max(fl, axis=1)
        reduced_ce = tf.reduce_max(ce, axis=1)
        return tf.reduce_mean((1 - ce_weight) * reduced_fl + ce_weight * reduced_ce)
        return tf.reduce_mean(reduced_fl)
    return combined_loss_fixed

ce_weights_list = [0., 0.3, 0.5, 0.7, 1]

# %%
import itertools
results = {}

for i, ce_w in enumerate(ce_weights_list):
    print("Numbers of exp: %i, ce_weight: %.2f" % (i, ce_w))

    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    """Code Here
    將自定義的 loss function 加入模型
    """
    model.compile(loss=combined_loss(ce_w), metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True
             )
    
    # Collect results
    exp_name_tag = ("exp-%s" % (i))
    results[exp_name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-acc': model.history.history["accuracy"],
                             'valid-acc': model.history.history["val_accuracy"]}
# Out:
# Numbers of exp: 0, ce_weight: 0.00
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 5s 107us/step - loss: 5.9647 - accuracy: 0.3358 - val_loss: 6.5064 - val_accuracy: 0.2415
# Epoch 2/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 4.3761 - accuracy: 0.4457 - val_loss: 5.5352 - val_accuracy: 0.3240
# Epoch 3/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 3.9639 - accuracy: 0.4839 - val_loss: 4.8157 - val_accuracy: 0.4015
# Epoch 4/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 3.6904 - accuracy: 0.5080 - val_loss: 4.4076 - val_accuracy: 0.4365
# Epoch 5/25
# 50000/50000 [==============================] - 5s 90us/step - loss: 3.4687 - accuracy: 0.5313 - val_loss: 4.1784 - val_accuracy: 0.4586
# Epoch 6/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 3.2885 - accuracy: 0.5483 - val_loss: 4.1299 - val_accuracy: 0.4561
# Epoch 7/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 3.1186 - accuracy: 0.5658 - val_loss: 3.9349 - val_accuracy: 0.4742
# Epoch 8/25
# 50000/50000 [==============================] - 5s 93us/step - loss: 2.9604 - accuracy: 0.5835 - val_loss: 4.0631 - val_accuracy: 0.4612
# Epoch 9/25
# 50000/50000 [==============================] - 5s 93us/step - loss: 2.8226 - accuracy: 0.5951 - val_loss: 4.0989 - val_accuracy: 0.4614
# Epoch 10/25
# 50000/50000 [==============================] - 5s 94us/step - loss: 2.6774 - accuracy: 0.6123 - val_loss: 3.9299 - val_accuracy: 0.4799
# Epoch 11/25
# 50000/50000 [==============================] - 5s 96us/step - loss: 2.5382 - accuracy: 0.6280 - val_loss: 3.9601 - val_accuracy: 0.4758
# Epoch 12/25
# 50000/50000 [==============================] - 5s 95us/step - loss: 2.4148 - accuracy: 0.6402 - val_loss: 3.9259 - val_accuracy: 0.4809
# Epoch 13/25
# 50000/50000 [==============================] - 5s 94us/step - loss: 2.2820 - accuracy: 0.6573 - val_loss: 4.0165 - val_accuracy: 0.4812
# Epoch 14/25
# 50000/50000 [==============================] - 5s 95us/step - loss: 2.1509 - accuracy: 0.6709 - val_loss: 4.0720 - val_accuracy: 0.4712
# Epoch 15/25
# 50000/50000 [==============================] - 5s 96us/step - loss: 2.0545 - accuracy: 0.6826 - val_loss: 4.2632 - val_accuracy: 0.4594
# Epoch 16/25
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.9591 - accuracy: 0.6971 - val_loss: 4.0610 - val_accuracy: 0.4808
# Epoch 17/25
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.8343 - accuracy: 0.7105 - val_loss: 4.1371 - val_accuracy: 0.4787
# Epoch 18/25
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.7184 - accuracy: 0.7268 - val_loss: 4.2704 - val_accuracy: 0.4716
# Epoch 19/25
# 50000/50000 [==============================] - 5s 98us/step - loss: 1.6167 - accuracy: 0.7373 - val_loss: 4.2506 - val_accuracy: 0.4726
# Epoch 20/25
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.5159 - accuracy: 0.7506 - val_loss: 4.3484 - val_accuracy: 0.4777
# Epoch 21/25
# 50000/50000 [==============================] - 5s 98us/step - loss: 1.4164 - accuracy: 0.7641 - val_loss: 4.4777 - val_accuracy: 0.4736
# Epoch 22/25
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.3302 - accuracy: 0.7757 - val_loss: 4.7966 - val_accuracy: 0.4605
# Epoch 23/25
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.2286 - accuracy: 0.7908 - val_loss: 4.4862 - val_accuracy: 0.4830
# Epoch 24/25
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.1392 - accuracy: 0.8023 - val_loss: 4.4847 - val_accuracy: 0.4773
# Epoch 25/25
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.0415 - accuracy: 0.8191 - val_loss: 4.7297 - val_accuracy: 0.4697
# Numbers of exp: 1, ce_weight: 0.30
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 5s 103us/step - loss: 4.9300 - accuracy: 0.3186 - val_loss: 5.3322 - val_accuracy: 0.2280
# Epoch 2/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 3.6228 - accuracy: 0.4364 - val_loss: 4.3922 - val_accuracy: 0.3338
# Epoch 3/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 3.2893 - accuracy: 0.4767 - val_loss: 3.9108 - val_accuracy: 0.4129
# Epoch 4/25
# 50000/50000 [==============================] - 5s 92us/step - loss: 3.0743 - accuracy: 0.5036 - val_loss: 3.6040 - val_accuracy: 0.4402
# Epoch 5/25
# 50000/50000 [==============================] - 5s 95us/step - loss: 2.9157 - accuracy: 0.5235 - val_loss: 3.4228 - val_accuracy: 0.4555
# Epoch 6/25
# 50000/50000 [==============================] - 5s 94us/step - loss: 2.7739 - accuracy: 0.5411 - val_loss: 3.3312 - val_accuracy: 0.4666
# Epoch 7/25
# 50000/50000 [==============================] - 5s 94us/step - loss: 2.6466 - accuracy: 0.5598 - val_loss: 3.2769 - val_accuracy: 0.4729
# Epoch 8/25
# 50000/50000 [==============================] - 5s 92us/step - loss: 2.5234 - accuracy: 0.5756 - val_loss: 3.2205 - val_accuracy: 0.4722
# Epoch 9/25
# 50000/50000 [==============================] - 5s 95us/step - loss: 2.4182 - accuracy: 0.5883 - val_loss: 3.3109 - val_accuracy: 0.4599
# Epoch 10/25
# 50000/50000 [==============================] - 5s 90us/step - loss: 2.3184 - accuracy: 0.6028 - val_loss: 3.2033 - val_accuracy: 0.4731
# Epoch 11/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 2.2184 - accuracy: 0.6174 - val_loss: 3.2033 - val_accuracy: 0.4798
# Epoch 12/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 2.1187 - accuracy: 0.6296 - val_loss: 3.1476 - val_accuracy: 0.4851
# Epoch 13/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 2.0203 - accuracy: 0.6451 - val_loss: 3.1933 - val_accuracy: 0.4884
# Epoch 14/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.9212 - accuracy: 0.6600 - val_loss: 3.1703 - val_accuracy: 0.4933
# Epoch 15/25
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.8373 - accuracy: 0.6723 - val_loss: 3.3218 - val_accuracy: 0.4802
# Epoch 16/25
# 50000/50000 [==============================] - 5s 92us/step - loss: 1.7441 - accuracy: 0.6841 - val_loss: 3.2178 - val_accuracy: 0.4971
# Epoch 17/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.6648 - accuracy: 0.6974 - val_loss: 3.2945 - val_accuracy: 0.4799
# Epoch 18/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.5760 - accuracy: 0.7102 - val_loss: 3.3009 - val_accuracy: 0.4887
# Epoch 19/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.4936 - accuracy: 0.7232 - val_loss: 3.3613 - val_accuracy: 0.4880
# Epoch 20/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.4111 - accuracy: 0.7392 - val_loss: 3.3560 - val_accuracy: 0.4909
# Epoch 21/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.3320 - accuracy: 0.7509 - val_loss: 3.4416 - val_accuracy: 0.4854
# Epoch 22/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.2551 - accuracy: 0.7635 - val_loss: 3.4266 - val_accuracy: 0.4869
# Epoch 23/25
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.1797 - accuracy: 0.7769 - val_loss: 3.4654 - val_accuracy: 0.4909
# Epoch 24/25
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.1059 - accuracy: 0.7892 - val_loss: 3.5961 - val_accuracy: 0.4893
# Epoch 25/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.0378 - accuracy: 0.8008 - val_loss: 3.6271 - val_accuracy: 0.4814
# Numbers of exp: 2, ce_weight: 0.50
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 5s 103us/step - loss: 4.1998 - accuracy: 0.3111 - val_loss: 4.5292 - val_accuracy: 0.1801
# Epoch 2/25
# 50000/50000 [==============================] - 4s 88us/step - loss: 3.1074 - accuracy: 0.4263 - val_loss: 3.9015 - val_accuracy: 0.2986
# Epoch 3/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 2.8365 - accuracy: 0.4672 - val_loss: 3.3926 - val_accuracy: 0.4023
# Epoch 4/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 2.6624 - accuracy: 0.4933 - val_loss: 3.1438 - val_accuracy: 0.4221
# Epoch 5/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 2.5335 - accuracy: 0.5113 - val_loss: 2.9699 - val_accuracy: 0.4572
# Epoch 6/25
# 50000/50000 [==============================] - 4s 88us/step - loss: 2.4226 - accuracy: 0.5290 - val_loss: 2.8371 - val_accuracy: 0.4666
# Epoch 7/25
# 50000/50000 [==============================] - 4s 88us/step - loss: 2.3188 - accuracy: 0.5468 - val_loss: 2.8085 - val_accuracy: 0.4665
# Epoch 8/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 2.2206 - accuracy: 0.5623 - val_loss: 2.7738 - val_accuracy: 0.4743
# Epoch 9/25
# 50000/50000 [==============================] - 4s 88us/step - loss: 2.1471 - accuracy: 0.5759 - val_loss: 2.7089 - val_accuracy: 0.4823
# Epoch 10/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 2.0678 - accuracy: 0.5889 - val_loss: 2.7113 - val_accuracy: 0.4871
# Epoch 11/25
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.9886 - accuracy: 0.6015 - val_loss: 2.6845 - val_accuracy: 0.4926
# Epoch 12/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.9114 - accuracy: 0.6147 - val_loss: 2.6725 - val_accuracy: 0.4955
# Epoch 13/25
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.8390 - accuracy: 0.6285 - val_loss: 2.6490 - val_accuracy: 0.4943
# Epoch 14/25
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.7740 - accuracy: 0.6389 - val_loss: 2.6428 - val_accuracy: 0.4990
# Epoch 15/25
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.7039 - accuracy: 0.6514 - val_loss: 2.7254 - val_accuracy: 0.4935
# Epoch 16/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.6348 - accuracy: 0.6659 - val_loss: 2.7047 - val_accuracy: 0.4959
# Epoch 17/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.5680 - accuracy: 0.6776 - val_loss: 2.7291 - val_accuracy: 0.4908
# Epoch 18/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.5039 - accuracy: 0.6884 - val_loss: 2.7670 - val_accuracy: 0.4948
# Epoch 19/25
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.4395 - accuracy: 0.7018 - val_loss: 2.8342 - val_accuracy: 0.4875
# Epoch 20/25
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.3784 - accuracy: 0.7120 - val_loss: 2.7602 - val_accuracy: 0.4913
# Epoch 21/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.3145 - accuracy: 0.7255 - val_loss: 2.9753 - val_accuracy: 0.4763
# Epoch 22/25
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.2550 - accuracy: 0.7366 - val_loss: 2.8364 - val_accuracy: 0.4936
# Epoch 23/25
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.1928 - accuracy: 0.7490 - val_loss: 2.8219 - val_accuracy: 0.4936
# Epoch 24/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.1321 - accuracy: 0.7623 - val_loss: 2.9276 - val_accuracy: 0.4894
# Epoch 25/25
# 50000/50000 [==============================] - 5s 92us/step - loss: 1.0788 - accuracy: 0.7731 - val_loss: 2.9813 - val_accuracy: 0.4875
# Numbers of exp: 3, ce_weight: 0.70
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 5s 103us/step - loss: 3.4976 - accuracy: 0.3011 - val_loss: 3.5061 - val_accuracy: 0.2115
# Epoch 2/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 2.5716 - accuracy: 0.4209 - val_loss: 3.1392 - val_accuracy: 0.2994
# Epoch 3/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 2.3465 - accuracy: 0.4625 - val_loss: 2.7977 - val_accuracy: 0.3756
# Epoch 4/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 2.2183 - accuracy: 0.4879 - val_loss: 2.5586 - val_accuracy: 0.4166
# Epoch 5/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 2.1117 - accuracy: 0.5089 - val_loss: 2.4131 - val_accuracy: 0.4461
# Epoch 6/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 2.0275 - accuracy: 0.5270 - val_loss: 2.3256 - val_accuracy: 0.4604
# Epoch 7/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.9506 - accuracy: 0.5429 - val_loss: 2.2733 - val_accuracy: 0.4632
# Epoch 8/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.8833 - accuracy: 0.5573 - val_loss: 2.2346 - val_accuracy: 0.4721
# Epoch 9/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.8197 - accuracy: 0.5690 - val_loss: 2.2321 - val_accuracy: 0.4754
# Epoch 10/25
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.7600 - accuracy: 0.5844 - val_loss: 2.2048 - val_accuracy: 0.4784
# Epoch 11/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.7056 - accuracy: 0.5968 - val_loss: 2.1907 - val_accuracy: 0.4871
# Epoch 12/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.6498 - accuracy: 0.6074 - val_loss: 2.1969 - val_accuracy: 0.4862
# Epoch 13/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.5981 - accuracy: 0.6192 - val_loss: 2.2548 - val_accuracy: 0.4792
# Epoch 14/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.5519 - accuracy: 0.6309 - val_loss: 2.2324 - val_accuracy: 0.4842
# Epoch 15/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.5021 - accuracy: 0.6386 - val_loss: 2.2082 - val_accuracy: 0.4848
# Epoch 16/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.4535 - accuracy: 0.6523 - val_loss: 2.1911 - val_accuracy: 0.4965
# Epoch 17/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.4046 - accuracy: 0.6645 - val_loss: 2.2326 - val_accuracy: 0.4867
# Epoch 18/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.3565 - accuracy: 0.6761 - val_loss: 2.2624 - val_accuracy: 0.4825
# Epoch 19/25
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.3133 - accuracy: 0.6866 - val_loss: 2.2361 - val_accuracy: 0.4905
# Epoch 20/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.2689 - accuracy: 0.6969 - val_loss: 2.2505 - val_accuracy: 0.4935
# Epoch 21/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.2276 - accuracy: 0.7068 - val_loss: 2.2812 - val_accuracy: 0.4878
# Epoch 22/25
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.1834 - accuracy: 0.7168 - val_loss: 2.3051 - val_accuracy: 0.4852
# Epoch 23/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.1419 - accuracy: 0.7284 - val_loss: 2.2981 - val_accuracy: 0.4903
# Epoch 24/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.0961 - accuracy: 0.7376 - val_loss: 2.2904 - val_accuracy: 0.4962
# Epoch 25/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.0567 - accuracy: 0.7470 - val_loss: 2.3020 - val_accuracy: 0.4900
# Numbers of exp: 4, ce_weight: 1.00
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 5s 105us/step - loss: 2.2372 - accuracy: 0.2702 - val_loss: 2.1248 - val_accuracy: 0.2174
# Epoch 2/25
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.7476 - accuracy: 0.3917 - val_loss: 1.9755 - val_accuracy: 0.2965
# Epoch 3/25
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.6234 - accuracy: 0.4342 - val_loss: 1.8215 - val_accuracy: 0.3693
# Epoch 4/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.5508 - accuracy: 0.4598 - val_loss: 1.7229 - val_accuracy: 0.3988
# Epoch 5/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.4928 - accuracy: 0.4789 - val_loss: 1.6380 - val_accuracy: 0.4302
# Epoch 6/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.4453 - accuracy: 0.4962 - val_loss: 1.5931 - val_accuracy: 0.4401
# Epoch 7/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.4048 - accuracy: 0.5110 - val_loss: 1.5473 - val_accuracy: 0.4554
# Epoch 8/25
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.3673 - accuracy: 0.5247 - val_loss: 1.5311 - val_accuracy: 0.4651
# Epoch 9/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.3335 - accuracy: 0.5363 - val_loss: 1.5183 - val_accuracy: 0.4622
# Epoch 10/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.3009 - accuracy: 0.5489 - val_loss: 1.5060 - val_accuracy: 0.4697
# Epoch 11/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.2737 - accuracy: 0.5586 - val_loss: 1.4846 - val_accuracy: 0.4774
# Epoch 12/25
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.2462 - accuracy: 0.5696 - val_loss: 1.4843 - val_accuracy: 0.4787
# Epoch 13/25
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.2175 - accuracy: 0.5793 - val_loss: 1.4721 - val_accuracy: 0.4808
# Epoch 14/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.1932 - accuracy: 0.5883 - val_loss: 1.4698 - val_accuracy: 0.4831
# Epoch 15/25
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.1675 - accuracy: 0.5990 - val_loss: 1.4827 - val_accuracy: 0.4763
# Epoch 16/25
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.1460 - accuracy: 0.6064 - val_loss: 1.4697 - val_accuracy: 0.4878
# Epoch 17/25
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.1206 - accuracy: 0.6162 - val_loss: 1.4645 - val_accuracy: 0.4816
# Epoch 18/25
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.0978 - accuracy: 0.6249 - val_loss: 1.4630 - val_accuracy: 0.4876
# Epoch 19/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.0755 - accuracy: 0.6331 - val_loss: 1.4655 - val_accuracy: 0.4885
# Epoch 20/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.0535 - accuracy: 0.6410 - val_loss: 1.4714 - val_accuracy: 0.4885
# Epoch 21/25
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.0319 - accuracy: 0.6502 - val_loss: 1.4685 - val_accuracy: 0.4867
# Epoch 22/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.0111 - accuracy: 0.6586 - val_loss: 1.4580 - val_accuracy: 0.4925
# Epoch 23/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 0.9884 - accuracy: 0.6671 - val_loss: 1.4665 - val_accuracy: 0.4866
# Epoch 24/25
# 50000/50000 [==============================] - 5s 90us/step - loss: 0.9697 - accuracy: 0.6740 - val_loss: 1.4708 - val_accuracy: 0.4921
# Epoch 25/25
# 50000/50000 [==============================] - 5s 91us/step - loss: 0.9492 - accuracy: 0.6827 - val_loss: 1.4744 - val_accuracy: 0.4899

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline
NUM_COLORS = len(results.keys())

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(NUM_COLORS)]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
